# %%
import os

# Replace with your actual PyPI API token
os.environ['TWINE_USERNAME'] = 'token'
os.environ['TWINE_PASSWORD'] = ''

# Upload the package
# !twine upload C:/Projects/Machine-Learning-UCT513/topsis_package/dist/*
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading topsis102218038-0.1.0-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/6.4 kB • --:-- • ?
# 100% ---------------------------------------- 6.4/6.4 kB • 00:00 • ?
# 100% ---------------------------------------- 6.4/6.4 kB • 00:00 • ?
# 100% ---------------------------------------- 6.4/6.4 kB • 00:00 • ?
# 100% ---------------------------------------- 6.4/6.4 kB • 00:00 • ?
# 100% ---------------------------------------- 6.4/6.4 kB • 00:00 • ?
# ...
